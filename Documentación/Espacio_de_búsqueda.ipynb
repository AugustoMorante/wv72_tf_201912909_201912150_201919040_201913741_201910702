# %% [markdown]
# ###Espacio de Búsqueda
#
# ##Estado Inicial
#
# Entre 50 y 100 puntos de distribución (almacenes).
# Entre 25000 y 5000 puntos de entrega.
# Una cantidad ilimitada de vehículos.
# Costo por tiempo y distancia por cada vehículo.
#
# (Ejemplo, no representa todos los puntos de distribución y puntos de entrega)
# Representacion logica
#
# ![p1CA.png](data:image/png;base64,...)
#
# ##Matriz de Adyacencia
#
# ![p2CA.png](data:image/png;base64,...)
#
# ##Estado Objetivo:
# Entregar a cada uno de los puntos de distribución bajo los siguientes requerimientos:
#  - Menor tiempo posible.
#  - Menor distancia recorrida por combustible.
#
# (Siguiendo ejemplo previo y empezando de 0)
#
# ![p3CA.png](data:image/png;base64,...)
#
# ###Acciones:
#
# ##Espacio de búsqueda:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
